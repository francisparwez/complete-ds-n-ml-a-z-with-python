# %% [markdown]
# # **ARRAY**
# ### *It is a data structure in the NumPy Library. You can think of it as a List, Dictionary, or Tuple.*

# %%
import numpy as np

# %%
np.array([2, 4, 6, 8])
# Out:
# array([2, 4, 6, 8])

# %%
variable = [5.8, 9, 7, 5]

# %%
print(type(variable[0]))
print(type(variable[1]))
# Out:
# <class 'float'>
# <class 'int'>

# %%
new_variable = np.array([5.8, 9, 7, 5])

# %%
new_variable
# Out:
# array([5.8, 9. , 7. , 5. ])

# %%
new_variable2 = np.array([5.8, 9, 7, 5], dtype="int")

# %%
new_variable2
# Out:
# array([5, 9, 7, 5])
